# %%
import pandas as pd

# %%
df=pd.read_csv('../data/bakery.csv')
df
# Out:
#      data-product-id                                  data-product-name  \
# 0             872615                         Mr Kipling Viennese Whirls
# 1              56312                          Mr Kipling French Fancies
# 2             684311                          Mr Kipling 8 Angel Slices
# 3             540706                     Waitrose 4 Brioche Burger Buns
# 4             783454     Hovis Seed Sensations Multiseeded Sliced Bread
# ..               ...                                                ...
# 480           384230                         Galaxy Chocolate Cake Bars
# 481           376437                                 25cm Football Cake
# 482           374515  Waitrose Ready To Bake 4 All Butter Cinnamon S...
# 483           297903             Dr. Oetker Old School Cake Mix Vanilla
# 484            77133                 Cohens Bakery Buckingham Rye Bread
#
#     data-product-type  data-product-on-offer  data-product-index  \
# ...

# %%
selected_columns = ['data-product-id','data-product-name','data-product-type']
print(df[selected_columns])
# Out:
#      data-product-id                                  data-product-name  \
# 0             872615                         Mr Kipling Viennese Whirls
# 1              56312                          Mr Kipling French Fancies
# 2             684311                          Mr Kipling 8 Angel Slices
# 3             540706                     Waitrose 4 Brioche Burger Buns
# 4             783454     Hovis Seed Sensations Multiseeded Sliced Bread
# ..               ...                                                ...
# 480           384230                         Galaxy Chocolate Cake Bars
# 481           376437                                 25cm Football Cake
# 482           374515  Waitrose Ready To Bake 4 All Butter Cinnamon S...
# 483           297903             Dr. Oetker Old School Cake Mix Vanilla
# 484            77133                 Cohens Bakery Buckingham Rye Bread
#
#     data-product-type
# 0                   G
# 1                   G
# 2                   G
# ...

# %%
if df['product-name'].equals (df['data-product-name']):
    print(" The columns are identical ")
    df = df.drop(columns=['data-product-name'])

else:
    print("The columns are not identical. Dropping the Columns")
# Out:
#  The columns are identical

# %%
df = df.rename(columns= {
                'data-product-id':'product-id',
                'data-product-name':'pro_name',
                'data-product-type':'pro_type',
                'data-product-on-offer':'offer',
                'data-product-index':'index',
                'image-url':'url',
                'product-page':'page',
                'product-name':'name',
                'product-size':'size',
                'item-price':'price',
                'price-per-unit':'unit',
                'offer-description':'offer_desc',
                'category':'catgs'}
                )
df
# Out:
#      product-id                                           pro_name pro_type  \
# 0        872615                         Mr Kipling Viennese Whirls        G
# 1         56312                          Mr Kipling French Fancies        G
# 2        684311                          Mr Kipling 8 Angel Slices        G
# 3        540706                     Waitrose 4 Brioche Burger Buns        G
# 4        783454     Hovis Seed Sensations Multiseeded Sliced Bread        G
# ..          ...                                                ...      ...
# 480      384230                         Galaxy Chocolate Cake Bars        G
# 481      376437                                 25cm Football Cake        E
# 482      374515  Waitrose Ready To Bake 4 All Butter Cinnamon S...        G
# 483      297903             Dr. Oetker Old School Cake Mix Vanilla        G
# 484       77133                 Cohens Bakery Buckingham Rye Bread        G
#
# ...

# %%
item_price_list =df['price'].tolist()

new_list = []

for element in item_price_list:
    if '£' in element:
        new_element = element.replace('£', '')
    elif 'p' in element:
        new_element = element.replace('p','')
        new_element = '0.' + new_element
    else:
        new_element = element

    new_list.append(new_element)

df['price'] = new_list
df['price'] = df['price'].astype(float)

# %%
new_list

# %%
df.info()

# %%
df[["price"]]
# Out:
#       price
# 0     £1.98
# 1     £2.36
# 2     £2.96
# 3     £1.31
# 4     £1.90
# ..      ...
# 480   £2.25
# 481  £30.00
# 482   £2.60
# 483   £3.00
# 484   £2.10
#
# [485 rows x 1 columns]

# %%
df.loc[df['price'].str.contains('p'), 'price'] = df['price'].apply(lambda x: '0.'+str.replace(x,'p',''))

# %%
df[['price']]
# Out:
#       price
# 0     £1.98
# 1     £2.36
# 2     £2.96
# 3     £1.31
# 4     £1.90
# ..      ...
# 480   £2.25
# 481  £30.00
# 482   £2.60
# 483   £3.00
# 484   £2.10
#
# [485 rows x 1 columns]

# %%
df.loc[df['price'].str.contains('£'), 'price'] = df['price'].str.replace('£','')

# %%
df[["price"]]
# Out:
#      price
# 0     1.98
# 1     2.36
# 2     2.96
# 3     1.31
# 4     1.90
# ..     ...
# 480   2.25
# 481  30.00
# 482   2.60
# 483   3.00
# 484   2.10
#
# [485 rows x 1 columns]

# %%
df['price'] = df['price'].astype(float)
df[["price"]]
# Out:
#      price
# 0     1.98
# 1     2.36
# 2     2.96
# 3     1.31
# 4     1.90
# ..     ...
# 480   2.25
# 481  30.00
# 482   2.60
# 483   3.00
# 484   2.10
#
# [485 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product-id  485 non-null    int64
#  1   pro_name    485 non-null    object
#  2   pro_type    485 non-null    object
#  3   offer       485 non-null    bool
#  4   index       485 non-null    int64
#  5   url         485 non-null    object
#  6   page        485 non-null    object
#  7   name        485 non-null    object
#  8   size        482 non-null    object
#  9   price       485 non-null    object
#  10  unit        463 non-null    object
#  11  offer_desc  52 non-null     object
#  12  catgs       485 non-null    object
# dtypes: bool(1), int64(2), object(10)
# memory usage: 46.1+ KB

# %%
df.shape
# Out:
# (485, 13)

# %%
df.drop_duplicates()
# Out:
#      product-id                                           pro_name pro_type  \
# 0        872615                         Mr Kipling Viennese Whirls        G
# 1         56312                          Mr Kipling French Fancies        G
# 2        684311                          Mr Kipling 8 Angel Slices        G
# 3        540706                     Waitrose 4 Brioche Burger Buns        G
# 4        783454     Hovis Seed Sensations Multiseeded Sliced Bread        G
# ..          ...                                                ...      ...
# 480      384230                         Galaxy Chocolate Cake Bars        G
# 481      376437                                 25cm Football Cake        E
# 482      374515  Waitrose Ready To Bake 4 All Butter Cinnamon S...        G
# 483      297903             Dr. Oetker Old School Cake Mix Vanilla        G
# 484       77133                 Cohens Bakery Buckingham Rye Bread        G
#
# ...
